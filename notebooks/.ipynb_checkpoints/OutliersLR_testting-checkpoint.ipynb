# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Loading

# %%
tracers = np.array(['Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Ba', 'La', 'Ce', 'Pr',
       'Nd', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu',
       'Hf', 'Ta', 'Th', 'U', 'Ni'], dtype=object)

morbs = "/Users/jenifervivar/Documents/GitHub/OceanBasaltML/basalts thesis/src/data/Combined_data_MORB.csv"
df_morbs = pd.read_csv(morbs)


p_ = r"/Users/jenifervivar/Documents/GitHub/OceanBasaltML/basalts thesis/src/data/combined_datasets"
combined_df = pd.read_csv(p_)
combined_df["Tectonic_Setting"] = combined_df["Tectonic_Setting"].str.strip()
c_df = combined_df.drop(["loc_keywords", "Location", "REFERENCE #", "ANALYZED MATERIAL", "SAMPLE NAME"], axis = 1)

both_df = pd.concat([c_df, df_morbs], axis = 0)
both_df.dropna(inplace = True)

import geopandas as gpd
p = "/Users/jenifervivar/Desktop/World_Countries_(Generalized)"
p1 = "/Users/jenifervivar/Desktop/tectonicplates-master"
#p = "/Users/jenifervivar/Desktop/World_Countries__Generalized_.shp"

world_map = gpd.read_file(p1)
world_map1=gpd.read_file(p)

# %% [markdown]
# ## defining X, X

# %%
X = both_df[tracers]
Y = both_df["Tectonic_Setting"]
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,Y,\
                                                    test_size=0.3, random_state=100, shuffle=True)

from imblearn.over_sampling import RandomOverSampler
over_sampler = RandomOverSampler(random_state=42)
X_bal, y_bal = over_sampler.fit_resample(X_train, y_train)

# %% [markdown]
# ## Trying to get known outliers from dataset

# %%
morbs = both_df.loc[(both_df["LONGITUDE"] > -10) & (both_df["LONGITUDE"] <30) &(both_df["Tectonic_Setting"] == "MORB")\
                   &((both_df["LATITUDE"] > -50) & (both_df["LATITUDE"] <-10))]

# %%
outliers_idx = [idx for idx in morbs.index.values]
outliers_idx
# Out:
# [1534,
#  1535,
#  1536,
#  1537,
#  1538,
#  1539,
#  2330,
#  2331,
#  2332,
#  2333,
#  2334,
#  2335,
#  2336,
#  2337,
#  2338,
#  2339,
#  2340,
#  2341,
#  2342,
#  2343,
#  2344,
#  2345,
#  4538,
#  4539,
#  4542,
#  4543,
#  4544,
#  4545]

# %%
len(outliers_idx)
# Out:
# 28

# %%
fig, ax = plt.subplots(figsize=(15,15))
world_map1.plot(ax=ax, alpha=0.4, color='blue')
world_map.plot(ax=ax, alpha=0.4, color='grey')

sns.scatterplot(x=morbs['LONGITUDE'].values, y=morbs["LATITUDE"].values, ax = ax, sizes=(40, 400))
plt.title("Location of Known Outliers")
plt.show()

# %% [markdown]
# ## Will the model perform better when the known outliers are removed?

# %%
free_df = both_df.drop(outliers_idx, axis = 0)
X = free_df[tracers]
Y = free_df["Tectonic_Setting"]
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,Y,\
                                                    test_size=0.3, random_state=100, shuffle=True)

from imblearn.over_sampling import RandomOverSampler
over_sampler = RandomOverSampler(random_state=42)
X_bal, y_bal = over_sampler.fit_resample(X_train, y_train)

# %%
x_test_bal, y_test_bal = over_sampler.fit_resample(X_test, y_test)

# %%
from sklearn.inspection import permutation_importance
import time
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import KFold

cv = RepeatedKFold(n_splits=10, n_repeats=10, random_state=1)
lr = LogisticRegression(C= 1, random_state = 1, multi_class = 'ovr', solver = 'lbfgs', penalty='l2', max_iter=5000)
# evaluate model
scores = cross_val_score(lr, X_bal, y_bal, scoring='accuracy', cv=cv, n_jobs=-1)
# report performance
print('Accuracy: %.3f (%.3f)' % (np.mean(scores), np.std(scores)))
# Out:
# Accuracy: 0.862 (0.013)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(C= 1, random_state = 1, multi_class = 'ovr', solver = 'lbfgs', penalty='l2', max_iter=5000)
lr.fit(X_bal, y_bal)
y_result = lr.predict(x_test_bal)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_bal, y_result, target_names=lr.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          IAB       0.94      0.83      0.88       984
#         MORB       0.81      0.94      0.87       984
#          OIB       0.90      0.86      0.88       984
#
#     accuracy                           0.87      2952
#    macro avg       0.88      0.87      0.87      2952
# weighted avg       0.88      0.87      0.87      2952

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
confusion_matrix_lr = confusion_matrix(y_test, y_result)
cm_display =ConfusionMatrixDisplay(confusion_matrix = confusion_matrix_lr, display_labels=lr.classes_) #,display_labels = [False, True])
cm_display.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/sk/km6c1g654036cmvl40zycd0m0000gn/T/ipykernel_1595/1200962717.py in <module>
#       1 from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# ----> 2 confusion_matrix_lr = confusion_matrix(y_test, y_result)
#       3 cm_display =ConfusionMatrixDisplay(confusion_matrix = confusion_matrix_lr, display_labels=lr.classes_) #,display_labels = [False, True])
#       4 cm_display.plot()
#       5 plt.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# ...

# %% [markdown]
# ## NOPE.. it did now perform better :(

# %%
imp_both_rf_lr = ['Rb', 'Sr', 'Nb', 'Ba', 'Pr', 'Eu', 'Yb', 'Ta', 'U', 'Ni']
sns.pairplot(combined_df[imp_both_rf_lr], hue=combined_df["Tectonic_Setting"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/sk/km6c1g654036cmvl40zycd0m0000gn/T/ipykernel_1595/3528921528.py in <module>
#       1 imp_both_rf_lr = ['Rb', 'Sr', 'Nb', 'Ba', 'Pr', 'Eu', 'Yb', 'Ta', 'U', 'Ni']
# ----> 2 sns.pairplot(combined_df[imp_both_rf_lr], hue=combined_df["Tectonic_Setting"])
#       3 plt.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2094     # Set up the PairGrid
# ...

# %%
combined_df[imp_both_rf_lr] = scaler.fit_transform(combined_df[imp_both_rf_lr])

# %%
#kind="kde"
imp_both_rf_lr = ['Rb', 'Sr', 'Nb', 'Ba', 'Pr', 'Eu', 'Yb', 'Ta', 'U', 'Ni']
sns.pairplot(combined_df[imp_both_rf_lr], kind="kde")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/sk/km6c1g654036cmvl40zycd0m0000gn/T/ipykernel_1595/1269479176.py in <module>
#       1 #kind="kde"
#       2 imp_both_rf_lr = ['Rb', 'Sr', 'Nb', 'Ba', 'Pr', 'Eu', 'Yb', 'Ta', 'U', 'Ni']
# ----> 3 sns.pairplot(combined_df[imp_both_rf_lr], kind="kde")
#       4 plt.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
# ...

# %%
#x_test_bal, y_test_bal = over_sampler.fit_resample(X_test, y_test)
imp_both_rf_lr = ['Sr', 'Nb',  "Tectonic_Setting"]
sns.pairplot(combined_df[imp_both_rf_lr], hue="Tectonic_Setting", kind="kde")
plt.show()
