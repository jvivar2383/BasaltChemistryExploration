# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the data to analyze

# %%
p_ = r"/Users/jenifervivar/Documents/GitHub/OceanBasaltML/basalts thesis/src/data/combined_datasets"
combined_df = pd.read_csv(p_)
p = "/Users/jenifervivar/Documents/GitHub/OceanBasaltML/basalts thesis/src/data/variables_target_file"
sampled_df = pd.read_csv(p)
col = sampled_df.columns[:-3].values

# %%
col
# Out:
# array(['SiO2', 'TiO2', 'Al2O3', 'FeOT', 'MnO', 'MgO', 'CaO', 'Na2O',
#        'K2O', 'P2O5', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Ba', 'La', 'Ce', 'Pr',
#        'Nd', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu',
#        'Hf', 'Ta', 'Th', 'U', 'Cr', 'Ni'], dtype=object)

# %%
sampled_df.Tectonic_setting.value_counts()
# Out:
# IAB     3308
# OIB     1989
# MORB    1071
# Name: Tectonic_setting, dtype: int64

# %% [markdown]
# ### The StandardScaler module is used to normalized (mean 0 and std 1) the data so that I can better compare the features

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_standard = scaler.fit_transform(sampled_df[col])
sampled_df[col] = x_standard
combined_df[col] = x_standard

# %% [markdown]
# `Below I add the ratios that are tradionalilly compared in the geologist community to determine the type of tectonic setting base on their chemistry trace. Geologist look at isotopes and their ratios when compared to the natural components in each basalt. The main ratios analyzed are: SiO vs Nb/Y, SiO vs, FeOT/MgO, La/Sm vs Zr/Nb, Y/Nb vs Zr/Nb`

# %%
sampled_df.columns
# Out:
# Index(['SiO2', 'TiO2', 'Al2O3', 'FeOT', 'MnO', 'MgO', 'CaO', 'Na2O', 'K2O',
#        'P2O5', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Ba', 'La', 'Ce', 'Pr', 'Nd', 'Sm',
#        'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu', 'Hf', 'Ta', 'Th',
#        'U', 'Cr', 'Ni', 'LATITUDE', 'LONGITUDE', 'Tectonic_setting'],
#       dtype='object')

# %% [markdown]
# ## adding commonly used ratios

# %%
sampled_df["Nb/Y"] = sampled_df["Nb"]/sampled_df["Y"]
sampled_df["FeOT/MgO"]= sampled_df["FeOT"]/sampled_df["MgO"]
sampled_df["La/Sm"] = sampled_df["La"]/sampled_df["Sm"]
sampled_df["Zr/Nb"] = sampled_df["Zr"]/sampled_df["Nb"]
sampled_df["Y/Nb"]= sampled_df["Y"]/sampled_df["Nb"]

sampled_df["Nb/La"] = sampled_df["Nb"]/sampled_df["La"]
sampled_df["Th/Yb"] = sampled_df["Th"]/sampled_df["Yb"]
sampled_df["Zr/Y"] = sampled_df["Zr"]/sampled_df["Y"]
#sampled_df["Th/Yb"] = sampled_df["Th"]/sampled_df["Yb"]

# %%
newColsNames = np.array(["Nb/Y","FeOT/MgO","La/Sm","Zr/Nb","Y/Nb", "Nb/La", "Th/Yb", "Zr/Y"])

# %%
#selecting the old features and the newly added features
features = np.append(col, newColsNames)
X = sampled_df[features]

# %%
#this fucntions makes it easy to train a random forest tree witout copying and pasting the same code

def randomForestTraining(x, y, df, features):
    from sklearn.model_selection import train_test_split
    # X = sampled_df[col], y = sampled_df["Tectonic_setting"]
    X_train, X_test, y_train, y_test = train_test_split(x, y,\
                                                        test_size=0.3, random_state=100)

    from imblearn.over_sampling import RandomOverSampler
    over_sampler = RandomOverSampler(random_state=42)
    X_bal, y_bal = over_sampler.fit_resample(X_train, y_train)


    from sklearn.ensemble import RandomForestClassifier
    labels = df[features].columns.to_list()
    rf = RandomForestClassifier(n_estimators = 500, random_state = 1)
    rf.fit(X_bal, y_bal)
    
    feature_importance = rf.feature_importances_
    indices = np.argsort(feature_importance)[::-1]

    y_result= rf.predict(X_test)
    from sklearn.metrics import classification_report
    print(classification_report(y_test, y_result))

    return feature_importance[indices], y_result,y_test, X_test, rf

# %%
sampled_df.columns[:]
# Out:
# Index(['SiO2', 'TiO2', 'Al2O3', 'FeOT', 'MnO', 'MgO', 'CaO', 'Na2O', 'K2O',
#        'P2O5', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Ba', 'La', 'Ce', 'Pr', 'Nd', 'Sm',
#        'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu', 'Hf', 'Ta', 'Th',
#        'U', 'Cr', 'Ni', 'LATITUDE', 'LONGITUDE', 'Tectonic_setting', 'Nb/Y',
#        'FeOT/MgO', 'La/Sm', 'Zr/Nb', 'Y/Nb', 'Nb/La', 'Th/Yb', 'Zr/Y'],
#       dtype='object')

# %% [markdown]
# ## `permutation_importance` --> This procedure breaks the relationship between the feature and the target, thus the drop in the model score is indicative of how much the model depends on the feature. This technique benefits from being model agnostic and can be calculated many times with different permutations of the feature.

# %%
from sklearn.model_selection import train_test_split
# X = sampled_df[col], y = sampled_df["Tectonic_setting"]
X_train, X_test, y_train, y_test = train_test_split(X,sampled_df["Tectonic_setting"],\
                                                    test_size=0.3, random_state=100)

from imblearn.over_sampling import RandomOverSampler
over_sampler = RandomOverSampler(random_state=42)
X_bal, y_bal = over_sampler.fit_resample(X_train, y_train)


from sklearn.ensemble import RandomForestClassifier
labels = sampled_df[features].columns.to_list()
rf_ = RandomForestClassifier(n_estimators = 500, random_state = 1)

rf_.fit(X_bal, y_bal)

from sklearn.inspection import permutation_importance
import time

start_time = time.time()
result = permutation_importance(
    rf_, X_test, y_test, n_repeats=20, random_state=42, n_jobs=2
)
elapsed_time = time.time() - start_time
print(f"Elapsed time to compute the importances: {elapsed_time:.3f} seconds")

forest_importances = pd.Series(result.importances_mean, index=labels)
# Out:
# Error processing line 1 of /Users/jenifervivar/opt/anaconda3/lib/python3.9/site-packages/google_auth-1.4.2-py2.7-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "/Users/jenifervivar/opt/anaconda3/lib/python3.9/site.py", line 169, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 562, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored
# Error processing line 1 of /Users/jenifervivar/opt/anaconda3/lib/python3.9/site-packages/google_auth-1.4.2-py2.7-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "/Users/jenifervivar/opt/anaconda3/lib/python3.9/site.py", line 169, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 562, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored
# Error processing line 1 of /Users/jenifervivar/opt/anaconda3/lib/python3.9/site-packages/google_auth-1.4.2-py2.7-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "/Users/jenifervivar/opt/anaconda3/lib/python3.9/site.py", line 169, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 562, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored
# Error processing line 1 of /Users/jenifervivar/opt/anaconda3/lib/python3.9/site-packages/google_auth-1.4.2-py2.7-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "/Users/jenifervivar/opt/anaconda3/lib/python3.9/site.py", line 169, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 562, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored
# Elapsed time to compute the importances: 50.693 seconds

# %%
#orders the features by index and reverse the order
sorted_idx = forest_importances.argsort()[::-1]

# %% [markdown]
# ## seeing the model performance from the features with commonly used features

# %%
feature_importance = rf_.feature_importances_
#indices = np.argsort(feature_importance)[::-1]

y_result= rf_.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, y_result))
# Out:
#               precision    recall  f1-score   support
#
#          IAB       0.96      0.94      0.95      1003
#         MORB       0.91      0.87      0.89       328
#          OIB       0.91      0.96      0.94       580
#
#     accuracy                           0.94      1911
#    macro avg       0.93      0.92      0.93      1911
# weighted avg       0.94      0.94      0.94      1911

# %%
labels = np.array(labels)

# %%
sorted_idx_ = rf_.feature_importances_.argsort()[::-1]
fig, ax = plt.subplots(figsize= (10,8))
ax.set_title("Feature Importance using Random Forest Impurity Values")
ax.bar(labels[sorted_idx_],feature_importance[sorted_idx_], align = 'center')
ax.set_xticks(np.arange(len(labels)),labels = labels[sorted_idx],rotation = 90)
#plt.savefig("/Users/jenifervivar/Documents/GitHub/OceanBasaltML/basalts thesis/reports/figures/reg_features")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
forest_importances[sorted_idx].plot.bar(yerr=result.importances_mean[sorted_idx], ax=ax)
ax.set_title("Feature importances using permutation on full model")
ax.set_ylabel("Mean accuracy decrease")
fig.tight_layout()
plt.savefig("/Users/jenifervivar/Documents/GitHub/OceanBasaltML/basalts thesis/reports/figures/reg_features_permu")
plt.show()

# %%
misclassifiedMap(y_test, X_test, rf_, sampled_df, "Misclassifies sampled of Traditional Features")

# %%
forest_importances[sorted_idx]

# %% [markdown]
# # Old features with some new ratios

# %% [markdown]
# `The random forest tree performs relatively well for the amount of features use in the training set. The only label below 90% accuracy is the MORB tectonic setting. Despite this an accuracy of 94% is reached on the test data set`.

# %%
labels
# Out:
# array(['SiO2', 'TiO2', 'Al2O3', 'FeOT', 'MnO', 'MgO', 'CaO', 'Na2O',
#        'K2O', 'P2O5', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Ba', 'La', 'Ce', 'Pr',
#        'Nd', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu',
#        'Hf', 'Ta', 'Th', 'U', 'Cr', 'Ni', 'Nb/Y', 'FeOT/MgO', 'La/Sm',
#        'Zr/Nb', 'Y/Nb', 'Nb/La', 'Th/Yb', 'Zr/Y'], dtype='<U8')

# %% [markdown]
# ## the function help us see where the misclassified features are in a map

# %%
def misclassifiedMap(ytest, X_test, model, df, title):
    misclassified = np.where(y_test != model.predict(X_test))
    correct = np.where(y_test == model.predict(X_test))
    from mpl_toolkits.basemap import Basemap
    plt.figure(figsize=(10, 8))
    m = Basemap(projection='cyl')
    plt.title(title)
    m.drawmapboundary(fill_color='lightskyblue')
    m.fillcontinents(color='green',lake_color='aqua')
    m.drawcoastlines()
    #m.arcgisimage(server = "https://server.arcgisonline.com/arcgis/services", xpixels = 1500, verbose= True)
    m.scatter(df.iloc[correct[0]]["LONGITUDE"],df.iloc[correct[0]]["LATITUDE"], latlon=True, c = "orange")
    m.scatter(df.iloc[misclassified[0]]["LONGITUDE"],df.iloc[misclassified[0]]["LATITUDE"], latlon=True, c = "black", alpha = .3)
    plt.show()

# %%
#y_test = np.asarray(y_test)
misclassified = np.where(y_test != rf.predict(X_test))

# %%
correct = np.where(y_test == rf.predict(X_test))

# %%
from mpl_toolkits.basemap import Basemap
plt.figure(figsize=(10, 8))
m = Basemap(projection='cyl')
plt.title("Miscclassified Values in black")
m.drawmapboundary(fill_color='lightskyblue')
m.fillcontinents(color='green',lake_color='aqua')
m.drawcoastlines()
#m.arcgisimage(server = "https://server.arcgisonline.com/arcgis/services", xpixels = 1500, verbose= True)
m.scatter(sampled_df.iloc[correct[0]]["LONGITUDE"],sampled_df.iloc[correct[0]]["LATITUDE"], latlon=True, c = "orange")
m.scatter(sampled_df.iloc[misclassified[0]]["LONGITUDE"],sampled_df.iloc[misclassified[0]]["LATITUDE"], latlon=True, c = "black", alpha = 0.3)
plt.show()

# %% [markdown]
# # testing with the first 8 features only

# %%
features = ["Sr","TiO2", "CaO", "Nb/La", "K2O","Na2O","Ba","Ta"]
X = sampled_df[features]
print(f"Classification report for {len(features)} features \n")
fea_impo, y_result,y_test, X_test, rf = randomForestTraining(X, sampled_df["Tectonic_setting"], sampled_df,features)
# Out:
# Classification report for 8 features
#
#               precision    recall  f1-score   support
#
#          IAB       0.95      0.94      0.95      1003
#         MORB       0.91      0.84      0.87       328
#          OIB       0.89      0.94      0.91       580
#
#     accuracy                           0.92      1911
#    macro avg       0.92      0.91      0.91      1911
# weighted avg       0.93      0.92      0.92      1911

# %%
misclassifiedMap(y_test, X_test, rf, sampled_df)

# %% [markdown]
# # testing with 4 features only

# %%
X = sampled_df[features[:4]]
print(f"Classification report for {len(features)} features \n")
fea_impo, y_result,y_test, X_test, rf  = randomForestTraining(X, sampled_df["Tectonic_setting"], sampled_df,features)
# Out:
# Classification report for 8 features
#
#               precision    recall  f1-score   support
#
#          IAB       0.93      0.92      0.93      1003
#         MORB       0.83      0.80      0.82       328
#          OIB       0.85      0.89      0.87       580
#
#     accuracy                           0.89      1911
#    macro avg       0.87      0.87      0.87      1911
# weighted avg       0.89      0.89      0.89      1911

# %% [markdown]
# # Adding new ratios randomly

# %% [markdown]
# `I would like to now explore new ratios that could be useful in determining tectonic settings. I would do this ramdomly below:`

# %%
#reloading the original data frame so that the features added before are ignored
#sampled_df = pd.read_csv(p)
newColsNames = []
for numerator in sampled_df[col].columns:
    for denominator in sampled_df[col].columns:
        if numerator != denominator:
            name = numerator +"/"+ denominator
            if name not in sampled_df.columns:
                inverse = denominator + "/"+numerator
                if inverse not in sampled_df.columns:
                    sampled_df[name] = sampled_df[numerator]/sampled_df[denominator]
                    newColsNames.append(name)
            
print(len(newColsNames))
newColsNames = [*set(newColsNames)]
print(len(newColsNames))
features = col
features = np.append(features,newColsNames)
# Out:
# 623
# 623

# %%
sampled_df.replace([np.inf, -np.inf], np.nan, inplace=True)
sampled_df.dropna(inplace = True)
X = sampled_df[features]

# %%
from sklearn.model_selection import train_test_split
# X = sampled_df[col], y = sampled_df["Tectonic_setting"]
X_train, X_test, y_train, y_test = train_test_split(X,sampled_df["Tectonic_setting"],\
                                                    test_size=0.3, random_state=100)

from imblearn.over_sampling import RandomOverSampler
over_sampler = RandomOverSampler(random_state=42)
X_bal, y_bal = over_sampler.fit_resample(X_train, y_train)


from sklearn.ensemble import RandomForestClassifier
labels = np.array(sampled_df[features].columns.to_list())
rf = RandomForestClassifier(n_estimators = 500, random_state = 1)
rf.fit(X_bal, y_bal)

feature_importance = rf.feature_importances_
indices = np.argsort(feature_importance)[::-1]

y_result= rf.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, y_result))
# Out:
#               precision    recall  f1-score   support
#
#          IAB       0.95      0.96      0.95      1002
#         MORB       0.92      0.83      0.88       320
#          OIB       0.93      0.97      0.95       589
#
#     accuracy                           0.94      1911
#    macro avg       0.93      0.92      0.93      1911
# weighted avg       0.94      0.94      0.94      1911

# %%
from sklearn.inspection import permutation_importance
import time

start_time = time.time()
result = permutation_importance(
    rf, X_test, y_test, n_repeats=15, random_state=42, n_jobs=2
)
elapsed_time = time.time() - start_time
print(f"Elapsed time to compute the importances: {elapsed_time:.3f} seconds")

forest_importances = pd.Series(result.importances_mean, index=labels)
# Out:
# Error processing line 1 of /Users/jenifervivar/opt/anaconda3/lib/python3.9/site-packages/google_auth-1.4.2-py2.7-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "/Users/jenifervivar/opt/anaconda3/lib/python3.9/site.py", line 169, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 562, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored
# Error processing line 1 of /Users/jenifervivar/opt/anaconda3/lib/python3.9/site-packages/google_auth-1.4.2-py2.7-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "/Users/jenifervivar/opt/anaconda3/lib/python3.9/site.py", line 169, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 562, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/sk/km6c1g654036cmvl40zycd0m0000gn/T/ipykernel_1775/3337931910.py in <module>
#       3
#       4 start_time = time.time()
# ----> 5 result = permutation_importance(
#       6     rf, X_test, y_test, n_repeats=15, random_state=42, n_jobs=2
#       7 )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/inspection/_permutation_importance.py in permutation_importance(estimator, X, y, scoring, n_repeats, n_jobs, random_state, sample_weight, max_samples)
#     257     baseline_score = _weights_scorer(scorer, estimator, X, y, sample_weight)
#     258
# --> 259     scores = Parallel(n_jobs=n_jobs)(
#     260         delayed(_calculate_permutation_scores)(
#     261             estimator,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/opt/anaconda3/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     439                     return self.__get_result()
#     440
# --> 441                 self._condition.wait(timeout)
#     442
#     443                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/opt/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %%
forest_importances
# Out:
# SiO2        0.000107
# TiO2       -0.000179
# Al2O3      -0.000107
# FeOT       -0.000286
# MnO        -0.000036
#               ...
# K2O/Dy     -0.000357
# TiO2/CaO    0.000000
# FeOT/Y     -0.000429
# SiO2/Sr     0.000393
# Yb/Ni       0.000000
# Length: 666, dtype: float64

# %%
sorted_idx_ = forest_importances.argsort()[::-1]
sorted_idx_
# Out:
# MnO/Na2O    447
# Sr/Zr         6
# Yb/Cr       572
# Ce/Yb        14
# TiO2/Ni     446
#            ...
# MnO         179
# FeOT        397
# Al2O3        43
# TiO2        342
# SiO2        609
# Length: 659, dtype: int64

# %%
forest_importances
# Out:
# SiO2        0.000767
# TiO2        0.000105
# Al2O3      -0.000558
# FeOT        0.000907
# MnO        -0.000384
#               ...
# TiO2/Ni    -0.000454
# Ce/Yb       0.000000
# Yb/Cr       0.000035
# Sr/Zr       0.000558
# MnO/Na2O   -0.000244
# Length: 659, dtype: float64

# %%
for i in forest_importances.argsort()[::-1]:
    print(features[i])
# Out:
# K2O/Ta
# CaO
# Rb/Ta
# Nb
# K2O/Nb
# Sr/Ce
# Ba/Ta
# CaO/Lu
# Ta
# FeOT
# Na2O/U
# Sr/La
# Rb/Ba
# SiO2
# TiO2/CaO
# Ta/Th
# CaO/Hf
# Rb/Nb
# Sr/Zr
# Na2O/Sm
# Ta/U
# Al2O3/Tm
# U
# Na2O/Ba
# Rb
# Yb
# Nb/Lu
# Na2O/Ce
# Nb/Th
# Na2O/Ho
# FeOT/Tb
# Rb/Hf
# FeOT/Tm
# Dy/Th
# MgO/Nb
# CaO/La
# Sm/Th
# Lu/Ta
# Na2O/P2O5
# Nb/Ta
# Pr
# Al2O3/Sr
# Ho/Yb
# Na2O/Rb
# Nd/Lu
# CaO/Nd
# Sr/U
# CaO/Sm
# La
# Rb/La
# Eu
# Sm
# Ce/Th
# Na2O/Nd
# CaO/Ce
# Sm/Dy
# Sr
# Na2O/Pr
# Yb/Lu
# FeOT/Lu
# Tm/Lu
# Rb/Eu
# SiO2/Dy
# CaO/Na2O
# Ba
# Tm/Cr
# P2O5/Cr
# Er/Ni
# Na2O/Sr
# SiO2/Rb
# Ba/Th
# Ce/Cr
# SiO2/CaO
# Ho
# Nb/U
# Nd/Eu
# Pr/Tb
# Ce
# Sr/Nb
# Gd
# CaO/Zr
# Sm/Eu
# Zr/Ho
# SiO2/Yb
# TiO2/Cr
# Zr/U
# TiO2
# Th
# Sr/Y
# FeOT/Cr
# TiO2/Y
# Al2O3/Na2O
# Al2O3/Tb
# P2O5/Sr
# TiO2/K2O
# CaO/Tb
# CaO/U
# Ho/U
# Rb/Sr
# SiO2/Lu
# Nd/Cr
# Nb/Sm
# Y/Ba
# Lu/Ni
# Tb/Dy
# MgO/Pr
# Sr/Ba
# Na2O
# MnO/Zr
# Sr/Tb
# Al2O3/Nb
# Tb
# Ba/La
# Yb/Cr
# Na2O/Eu
# Al2O3/Ce
# MnO/Pr
# Na2O/K2O
# U/Cr
# CaO/Ho
# Al2O3/FeOT
# FeOT/Zr
# TiO2/FeOT
# Nb/Nd
# MgO/Gd
# Zr/Ba
# CaO/Rb
# Ba/Cr
# La/Cr
# Rb/Zr
# FeOT/Na2O
# Eu/Gd
# Pr/U
# Gd/Tb
# Tb/Er
# Zr/La
# Gd/Cr
# Pr/Gd
# La/Tb
# Tm/Yb
# K2O/Gd
# Ba/Yb
# Pr/Ho
# Th/Cr
# Na2O/Yb
# SiO2/Y
# Pr/Dy
# Ba/Gd
# MnO/K2O
# Th/Ni
# Sr/Cr
# Ce/Yb
# Al2O3/Dy
# Pr/Tm
# Tb/Yb
# La/Gd
# La/Hf
# Dy/Tm
# Ho/Er
# Nb/Tb
# Sm/Cr
# La/Yb
# CaO/Sr
# MnO/Hf
# Ho/Hf
# MnO/Yb
# La/Eu
# Gd/Er
# Eu/Yb
# Nb/Yb
# Sm/Tb
# Cr/Ni
# TiO2/Na2O
# CaO/Er
# P2O5/Dy
# La/Dy
# Na2O/Cr
# K2O/Y
# Ho/Tm
# TiO2/La
# Dy/Er
# MgO/Ni
# MgO/U
# Nd/Hf
# Hf/Th
# Na2O/Ni
# Sr/Yb
# Nb/Gd
# La/Th
# La/Tm
# Eu/U
# CaO/Yb
# Rb/Cr
# Ce/Ho
# MnO/Nb
# SiO2/Hf
# Dy/Cr
# Ho/Th
# FeOT/Pr
# TiO2/Nb
# Pr/Nd
# Sm/Gd
# SiO2/FeOT
# P2O5/Ba
# Ce/Dy
# Zr/Gd
# K2O/Dy
# Y/Pr
# Al2O3/Nd
# CaO/Ni
# Zr/Ce
# Gd/Dy
# Sr/Dy
# Nd/Tm
# Er/Lu
# Gd/Tm
# MnO/Sr
# Al2O3/MgO
# Gd/Yb
# Yb/Ni
# Sm/Hf
# MgO/Sm
# CaO/Tm
# MnO/Eu
# Y/Er
# Tb/Ho
# SiO2/Tm
# Pr/Er
# Eu/Ho
# K2O/Tm
# CaO/Th
# SiO2/Tb
# Ba/Dy
# TiO2/Ho
# Pr/Th
# SiO2/Cr
# MnO/P2O5
# Nb/Ho
# Dy/Hf
# SiO2/Ni
# Al2O3/Gd
# Rb/Sm
# Rb/Tm
# FeOT/Sm
# Ba/Hf
# CaO/Cr
# Na2O/Er
# MgO/Tm
# Y/Ta
# K2O/Hf
# Tb/U
# Y/Eu
# Al2O3/Y
# Y/Th
# MnO/Dy
# MgO/Er
# Na2O/Lu
# Sm/Er
# Tm/Th
# Nd/Ho
# MnO/Lu
# Zr/Eu
# Th/U
# Er
# Al2O3/Eu
# MgO/Na2O
# CaO/Y
# CaO/P2O5
# Tb/Hf
# Zr/Dy
# MnO/Ba
# Y/Gd
# MnO/Ho
# Na2O/Y
# FeOT/Y
# Al2O3/P2O5
# Ce/Hf
# TiO2/Hf
# TiO2/Er
# Sr/Er
# Ba/Ce
# Ce/Ta
# Na2O/Hf
# K2O/Sm
# Nd/Tb
# K2O/Eu
# Gd/Ho
# Nd/Dy
# MnO/Cr
# Al2O3/Er
# Nd/U
# Sm/Lu
# K2O/La
# La/Ta
# CaO/Ta
# FeOT/Er
# K2O/Yb
# TiO2/U
# FeOT/P2O5
# P2O5/Ni
# SiO2/Ce
# Ba/Tb
# K2O/Tb
# Eu/Ta
# CaO/K2O
# Tb/Th
# TiO2/Dy
# Y/Hf
# La/Pr
# FeOT/La
# Er/U
# TiO2/MnO
# TiO2/Th
# Er/Yb
# Pr/Yb
# Na2O/Gd
# SiO2/MnO
# MnO/MgO
# Zr
# Yb/Hf
# Al2O3/Yb
# Y/Cr
# Nd
# MnO/Ni
# Sr/Sm
# MnO/Tb
# CaO/Ba
# SiO2/TiO2
# SiO2/Zr
# Nd/Er
# SiO2/Ta
# Tm/U
# Al2O3/Hf
# Nd/Yb
# Zr/Ni
# Hf/Cr
# Zr/Yb
# MnO/Ce
# FeOT/Dy
# Y/La
# Zr/Hf
# FeOT/U
# Ce/Sm
# Zr/Th
# Ho/Cr
# Pr/Hf
# Rb/Th
# Hf
# Dy/Lu
# Al2O3/Ho
# P2O5/Nd
# Sr/Ho
# Na2O/Nb
# K2O/Th
# FeOT/Ta
# K2O/Lu
# Y/Dy
# MgO/Nd
# Eu/Tm
# Tm/Ni
# Rb/Dy
# FeOT/Rb
# Al2O3/Cr
# Eu/Th
# SiO2/P2O5
# Zr/Cr
# FeOT/Th
# Tm/Ta
# Lu/Th
# CaO/Dy
# Lu/Cr
# Na2O/Zr
# MgO/Rb
# FeOT/Gd
# MgO/Ce
# Al2O3/MnO
# P2O5/La
# Tb/Ni
# Rb/Tb
# Ba/Tm
# MgO/Eu
# Eu/Ni
# La/Ho
# MnO/Na2O
# MnO/Nd
# Dy/U
# Pr/Ni
# P2O5/Gd
# Pr/Cr
# P2O5/Rb
# Eu/Dy
# Gd/Ni
# Lu/U
# Gd/U
# MnO/Y
# Al2O3/Rb
# Al2O3/Pr
# TiO2/Ce
# Dy/Ni
# Ta/Ni
# Al2O3/U
# TiO2/Yb
# Gd/Ta
# TiO2/Gd
# Al2O3/Ni
# Pr/Lu
# Zr/Lu
# Sm/Ni
# Tb/Tm
# MnO/Er
# U/Ni
# SiO2/Nd
# Ce/Gd
# TiO2/Rb
# MnO/Sm
# MnO/Tm
# MnO/Ta
# Al2O3/Sm
# Na2O/Ta
# Nb/Cr
# Y/Ni
# SiO2/Al2O3
# Tb/Lu
# Y/Ho
# Al2O3/CaO
# Y/U
# Ce/Nd
# P2O5/Tm
# Rb/Er
# Er/Hf
# SiO2/MgO
# K2O/P2O5
# Nb/Eu
# Y/Nd
# Lu/Hf
# TiO2/Ta
# Zr/Tb
# P2O5/Eu
# MgO/Ba
# CaO/Nb
# Tb/Ta
# Sr/Tm
# Er/Th
# TiO2/Tb
# FeOT/Hf
# Nd/Th
# CaO/Gd
# SiO2/Nb
# Zr/Sm
# La/Er
# Sr/Hf
# Pr/Ta
# Sr/Nd
# P2O5/Yb
# Hf/Ni
# Zr/Nd
# La/Ce
# Er/Tm
# MgO/Ho
# K2O/Ba
# TiO2/Nd
# MgO/Yb
# MgO/Hf
# Zr/Pr
# MgO/P2O5
# K2O/Rb
# Ho/Ta
# P2O5/Th
# Sr/Gd
# TiO2/Al2O3
# Na2O/Dy
# FeOT/K2O
# Sr/Pr
# Dy/Ho
# Sr/Ni
# Sr/Th
# SiO2/Th
# Ce/U
# FeOT/Nd
# K2O/Sr
# Gd/Hf
# Y/Sm
# Ba/Ni
# SiO2/Sr
# Nd/Ta
# Er/Ta
# Y/Ce
# Tb/Cr
# Eu/Er
# P2O5/Nb
# Al2O3/Zr
# P2O5/Hf
# FeOT/Ba
# FeOT/Eu
# MnO
# Yb/Ta
# Dy/Ta
# CaO/Pr
# Rb/Ni
# Ho/Lu
# Al2O3/La
# Zr/Tm
# Ba/Lu
# Ba/Pr
# Ba/Ho
# Zr/Ta
# Ce/Tm
# Sm/U
# Ba/Sm
# Y/Tm
# Gd/Th
# Sm/Tm
# SiO2/Pr
# P2O5/Tb
# MgO/Lu
# SiO2/Na2O
# Rb/Y
# MgO/Sr
# K2O/Ho
# MgO/Cr
# Sm/Ta
# Tm
# Ce/Tb
# Eu/Tb
# Rb/Pr
# TiO2/Eu
# TiO2/Sr
# Yb/U
# Sm/Ho
# FeOT/Ni
# Al2O3/Ba
# FeOT/MnO
# K2O/Er
# Ho/Ni
# TiO2/Ni
# P2O5/Ho
# Na2O/Tm
# CaO/Eu
# K2O/Zr
# Nb/Ni
# K2O/Pr
# Al2O3/Ta
# TiO2/Zr
# La/Nd
# TiO2/MgO
# Cr
# P2O5/Ce
# Dy
# K2O
# Nb/Tm
# Hf/U
# SiO2/Er
# Nb/Er
# La/U
# SiO2/Ho
# Ce/Ni
# La/Ni
# FeOT/Nb
# TiO2/Ba
# Ni
# Ce/Er
# TiO2/Tm
# Al2O3/K2O
# Na2O/La
# K2O/Ni
# Nd/Ni
# P2O5/U
# Pr/Sm
# MgO/Zr
# Dy/Yb
# Ta/Cr
# Eu/Cr
# MnO/Rb
# Sr/Ta
# Ce/Lu
# Na2O/Tb
# Pr/Eu
# K2O/Cr
# K2O/U
# Hf/Ta
# MgO/La
# Ce/Pr
# MnO/La
# La/Lu
# Sm/Yb
# Zr/Er
# Nb/Ce
# MgO
# Al2O3
# Eu/Lu
# P2O5
# Er/Cr
# Rb/Ce
# MnO/Th
# Lu
# Sr/Lu
# Ba/U
# Rb/Gd
# Al2O3/Th
# MnO/Gd
# Eu/Hf
# TiO2/Sm
# FeOT/Ce
# Na2O/Th
# Nb/Pr
# MnO/U
# Nb/Dy
# MgO/Th
# Rb/Ho
# Ba/Eu
# SiO2/K2O
# MgO/CaO
# TiO2/P2O5
# Y
# SiO2/Gd
# FeOT/CaO
# MgO/Dy
# SiO2/U
# Nd/Gd
# P2O5/Er
# FeOT/Sr
# MgO/Tb
# Rb/Yb
# Nb/Hf
# P2O5/Lu
# MgO/Y
# SiO2/Eu
# K2O/Ce
# P2O5/Sm
# Y/Tb
# SiO2/La
# TiO2/Pr
# P2O5/Ta
# Rb/U
# FeOT/Ho
# Nb/Ba
# Nd/Sm
# P2O5/Y
# MnO/CaO
# FeOT/Yb
# Ce/Eu
# Rb/Lu
# P2O5/Zr
# Rb/Nd
# K2O/Nd
# Ba/Er
# Gd/Lu
# Y/Yb
# Tm/Hf
# TiO2/Lu
# Ba/Nd
# MgO/Ta
# MgO/K2O
# SiO2/Ba
# Y/Lu
# P2O5/Pr
# Al2O3/Lu
# SiO2/Sm
# Sr/Eu

# %%
"Nb/La" in sampled_df.columns.values
# Out:
# True

# %%
fig, ax = plt.subplots(figsize=(10,8))
forest_importances[sorted_idx_][:30].plot.bar(yerr=result.importances_std[sorted_idx_][:30], ax=ax)
ax.set_title("Feature importances using permutation on full model")
ax.set_ylabel("Mean accuracy decrease")
fig.tight_layout()
plt.savefig("/Users/jenifervivar/Documents/GitHub/OceanBasaltML/basalts thesis/reports/figures/random_features_rf")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
forest_importances[sorted_idx_][30:60].plot.bar(yerr=result.importances_std[sorted_idx_][30:60], ax=ax)
ax.set_title("Feature importances using permutation on full model")
ax.set_ylabel("Mean accuracy decrease")
fig.tight_layout()
plt.show()

# %%
sorted_idx_
# Out:
# Yb/Ni       462
# SiO2/Sr     340
# FeOT/Y      438
# TiO2/CaO    125
# K2O/Dy      664
#            ...
# MnO         559
# FeOT        312
# Al2O3       628
# TiO2        144
# SiO2        218
# Length: 666, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10,8))
forest_importances[sorted_idx_][60:120].plot.bar(yerr=result.importances_std[sorted_idx_][60:120], ax=ax)
ax.set_title("Feature importances using permutation on full model")
ax.set_ylabel("Mean accuracy decrease")
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
forest_importances[sorted_idx_][-60:-30].plot.bar(yerr=result.importances_std[sorted_idx_][-60:-30], ax=ax)
ax.set_title("Feature importances using permutation on full model")
ax.set_ylabel("Mean accuracy decrease")
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
forest_importances[:30].plot.bar(yerr=result.importances_std[:30], ax=ax)
ax.set_title("Feature importances using permutation on full model")
ax.set_ylabel("Mean accuracy decrease")
fig.tight_layout()
plt.show()

# %%
misclassifiedMap(y_test, X_test, rf, sampled_df, "Misclassification Location of Ramdom Features")

# %%
sorted_idx = rf.feature_importances_.argsort()[::-1]
fig, ax = plt.subplots(figsize= (10,8))
labels = np.array(labels)
ax.set_title("Feature Importance using Random Forest Impurity Values")
ax.bar(labels[sorted_idx][:15],feature_importance[sorted_idx][:15], align = 'center')
ax.set_xticks(np.arange(len(labels[:15])),labels = labels[sorted_idx][:15],rotation = 90)
plt.show()

# %%
np.array(["Nb/Y","FeOT/MgO","La/Sm","Zr/Nb","Y/Nb", "Nb/La", "Th/Yb", "Zr/Y"])

# %%
misclassifiedMap(y_test, X_test, rf, sampled_df)

# %% [markdown]
# ## feature importance for randomly made features

# %%
sorted_idx = rf.feature_importances_.argsort()[::-1]

# %%
np.array(features)[sorted_idx][:30]

# %%
feature_importance[sorted_idx][:30]

# %% [markdown]
# ### interesting facts about Nb as it is in the to 3 for important features in this model: `Niobium is used in alloys including stainless steel. It improves the strength of the alloys, particularly at low temperatures. Alloys containing niobium are used in jet engines and rockets, beams and girders for buildings and oil rigs, and oil and gas pipelines. This element also has superconducting properties.`

# %%
plt.figure(figsize= (10,8))
plt.title("Feature Importance using Random Forest Impurity Values")
plt.bar(np.array(features)[sorted_idx][:30],feature_importance[sorted_idx][:30], align = 'center')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize= (10,8))
plt.title("Feature Importance using Random Forest Impurity Values")
plt.bar(np.array(features)[sorted_idx][30:60],feature_importance[sorted_idx][30:60], align = 'center')
plt.xticks(rotation = 90)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
confusion_matrix = confusion_matrix(y_test, y_result)
cm_display =ConfusionMatrixDisplay(confusion_matrix = confusion_matrix) #,display_labels = [False, True])
cm_display.plot()
plt.show()

# %% [markdown]
# ### Random forest with 8 features only

# %%
X = sampled_df[np.array(features)[sorted_idx][:9]]
print("Classification report for 8 features \n")
fea_impo, y_res, y_test, X_test, rf = randomForestTraining(X, sampled_df["Tectonic_setting"], sampled_df,features)
# Out:
# Classification report for 8 features
#
#               precision    recall  f1-score   support
#
#          IAB       0.96      0.94      0.95      1002
#         MORB       0.89      0.83      0.86       320
#          OIB       0.89      0.96      0.92       589
#
#     accuracy                           0.93      1911
#    macro avg       0.91      0.91      0.91      1911
# weighted avg       0.93      0.93      0.93      1911

# %%
X

# %%
misclassifiedMap(y_test, X_test, rf, sampled_df)

# %% [markdown]
# ## Traing the random forest with the 4 most importan features as per the Gini value

# %%
X = sampled_df[np.array(features)[sorted_idx][:4]]

print("Classification report for 4 features \n")
fea_impo, y_res, y_test,X_test, rf = randomForestTraining(X, sampled_df["Tectonic_setting"], sampled_df,features)
# Out:
# Classification report for 4 features
#
#               precision    recall  f1-score   support
#
#          IAB       0.94      0.89      0.91      1002
#         MORB       0.78      0.84      0.81       320
#          OIB       0.85      0.90      0.88       589
#
#     accuracy                           0.88      1911
#    macro avg       0.86      0.88      0.87      1911
# weighted avg       0.89      0.88      0.88      1911

# %%
X

# %%
misclassifiedMap(y_test, X_test, rf, sampled_df)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
confusion_matrix = confusion_matrix(y_test, y_res)
cm_display =ConfusionMatrixDisplay(confusion_matrix = confusion_matrix) #,display_labels = [False, True])
cm_display.plot()
plt.show()

# %%
X = sampled_df[np.array(features)[sorted_idx][:2]]

print("Classification report for 4 features \n")
fea_impo, y_res, y_test,X_test, rf = randomForestTraining(X, sampled_df["Tectonic_setting"], sampled_df,features)
# Out:
# Classification report for 4 features
#
#               precision    recall  f1-score   support
#
#          IAB       0.89      0.83      0.86      1002
#         MORB       0.65      0.71      0.68       320
#          OIB       0.76      0.81      0.78       589
#
#     accuracy                           0.80      1911
#    macro avg       0.77      0.78      0.77      1911
# weighted avg       0.81      0.80      0.81      1911

# %%
X = sampled_df[np.array(features)[sorted_idx][:3]]

print("Classification report for 4 features \n")
fea_impo, y_res, y_test,X_test, rf = randomForestTraining(X, sampled_df["Tectonic_setting"], sampled_df,features)
# Out:
# Classification report for 4 features
#
#               precision    recall  f1-score   support
#
#          IAB       0.92      0.88      0.90      1002
#         MORB       0.75      0.78      0.77       320
#          OIB       0.83      0.86      0.84       589
#
#     accuracy                           0.86      1911
#    macro avg       0.83      0.84      0.84      1911
# weighted avg       0.86      0.86      0.86      1911
